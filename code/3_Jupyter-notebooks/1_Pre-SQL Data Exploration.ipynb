# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import sqlite3 as lite

# %%
# Function to get table names from database
def tables_in_sqlite_db(conn):
    cursor = conn.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = [
        v[0] for v in cursor.fetchall()
        if v[0] != "sqlite_sequence"
    ]
    cursor.close()
    return tables

# %%
# Get table names from database
conn = lite.connect('../unos.db')
tables = tables_in_sqlite_db(conn)
print(tables)
# Out:
# []

# %%
# QUERY database to create dataframe
query = f"SELECT * FROM (SELECT *, strftime('%Y', {'TX_DATE'}) as Year FROM {'kidpan_data'}) data WHERE Year = '2010'"
df_10 = pd.read_sql_query(query,conn)

# %%
df_10.shape
# Out:
# (18077, 482)

# %%
# From data dictionary: 
#CONTIN_IV_DRUG_OLD_DON = DECEASED DONOR-HISTORY OF IV DRUG USE+RECENT 6MO USE VAR START DATE = 4/1/94
# HBA1C_PA_TCR = HBA1C AT LISTING (PA KP ONLY) -- VAR START DATE: 2/28/18
# FREE_DON = LIVING DONOR-FREE CARE AS SECONDARY PAYMENT TYPE -- VAR START DATE: 10/25/99
# DONATION_DON = LIVING DONOR-DONATION AS SECONDARY PAYMENT TYPE -- VAR START DATE: 10/25/99
# SELF_DON = LIVING DONOR-SELF AS SECONDARY PAYMENT TYPE -- VAR START DATE: 10/25/99 VAR END 1/1/07
df_10.isnull().sum().sort_values(ascending = False)
# Out:
# CONTIN_IV_DRUG_OLD_DON    18077
# HBA1C_PA_TCR              18077
# FREE_DON                  18077
# DONATION_DON              18077
# SELF_DON                  18077
#                           ...
# DISTANCE                      0
# DIAL_TRR                      0
# ORGAN                         0
# CMV_IGG                       0
# index                         0
# Length: 482, dtype: int64

# %%
# Drop columns in which all values are null (482 --> 431 Features)
df_10.dropna(axis = 1, how = 'all', inplace = True) 
df_10.shape
# Out:
# (18077, 431)

# %%
df_10.isnull().sum().sort_values(ascending=False)
# Out:
# TXLNG                      18076
# C_PEPTIDE_PA_TCR           18076
# WLLU                       18076
# COD3_OSTXT_PA              18074
# PRI_PAYMENT_CTRY_TCR_PA    18074
#                            ...
# ORGAN                          0
# CMV_IGG                        0
# CMV_IGM                        0
# EBV_SEROSTATUS                 0
# index                          0
# Length: 431, dtype: int64

# %%
df_10.shape
# Out:
# (18077, 431)

# %% [markdown]
# #### Run a dynamic sql queery giving me the percentage of nulls per each column in a table.

# %%
# Kidpan Data
columns = list(df_10)
kidpan_nulls = pd.DataFrame()

for col in columns:
    
    query = f"""SELECT \'{col}\' as column, 1-CAST(COUNT("{col}") as float)/CAST(COUNT(*) as float) as percent_null FROM kidpan_data;"""
    tmp_table = pd.read_sql_query(query, conn)
    kidpan_nulls = pd.concat([kidpan_nulls, tmp_table])

# %%
kidpan_nulls.to_csv('../data/kidpan_nulls.csv', index = False)

# %%
kidpan_nulls = pd.read_csv('../data/kidpan_nulls.csv')
kidpan_nulls.head()
# Out:
#         column  percent_null
# 0        index      0.000000
# 1       WL_ORG      0.045441
# 2  NUM_PREV_TX      0.045441
# 3  CREAT_CLEAR      0.954463
# 4          GFR      0.733060

# %%
kidpan_nulls.set_index('column', inplace = True)
kidpan_nulls.head()
# Out:
#              percent_null
# column
# index            0.000000
# WL_ORG           0.045441
# NUM_PREV_TX      0.045441
# CREAT_CLEAR      0.954463
# GFR              0.733060

# %%
pd.set_option('display.max_rows', 450)
kidpan_nulls['percent_null'].sort_values(ascending = False)
# Out:
# column
# PRI_PAYMENT_CTRY_TRR_PA            0.999947
# PRI_PAYMENT_CTRY_TCR_PA            0.999945
# TXLNG                              0.999907
# COD3_OSTXT_PA                      0.999899
# WLLU                               0.999824
# COD3_PA                            0.999779
# BLOOD_SUGAR_MED_RESUMED_DATE_PA    0.999758
# BLOOD_SUGAR_DIET_PA                0.999666
# COD2_OSTXT_PA                      0.999642
# BLOOD_SUGAR_MEDICATION_PA          0.999586
# PRI_PAYMENT_CTRY_TCR_KI            0.999537
# PRI_PAYMENT_CTRY_TRR_KI            0.999494
# WLPI                               0.999457
# COD2_PA                            0.999264
# MALIG_OSTXT_TRR                    0.999157
# OTH_GRF_FAIL_CAUSE_OSTXT_PA        0.999012
# DGN2_OSTXT_TCR                     0.998799
# COD3_OSTXT_KI                      0.998596
# DUCT_MGMT_OSTXT                    0.998592
# TXINT                              0.998587
# OTH_COMPL_OSTXT                    0.998460
# DIAG_OSTXT_PA                      0.998447
# ENTERIC_DRAIN_DT                   0.998424
# ENTERIC_DRAIN                      0.998424
# CITIZEN_COUNTRY_DON                0.998387
# RECOV_COUNTRY                      0.998347
# GRF_FAIL_CAUSE_OSTXT_PA            0.998228
# INO_PROCURE_OSTXT_3                0.998154
# RETXDATE_PA                        0.998054
# PRVTXDIF_PA                        0.998044
# ART_RECON_OSTXT                    0.998000
# REJ_HYPER_PA                       0.997894
# TXHRT                              0.997870
# CANCER_OTH_OSTXT_DON               0.997784
# C_PEPTIDE_PA_TRR                   0.997718
# WLIN                               0.997493
# CITIZEN_COUNTRY                    0.997083
# COD_OSTXT_PA                       0.997023
# COD3_KI                            0.996988
# MALIG_TY_TRR                       0.996768
# HBA1C_PA_TRR                       0.996373
# INSULIN_RESUMED_DATE_PA            0.996143
# WLHR                               0.995725
# COD2_OSTXT_KI                      0.995133
# INO_PROCURE_AGENT_3                0.994933
# INSULIN_DUR_DON                    0.994765
# PX_NON_COMPL_PA                    0.994480
# PK_DDR2                            0.994439
# PK_DA2                             0.994437
# PK_DB2                             0.994422
# PK_DDR1                            0.994412
# PK_DA1                             0.994407
# PK_DB1                             0.994407
# YR_ENTRY_US_TCR                    0.994161
# INO_PROCURE_OSTXT_2                0.993674
# INO_PROCURE_OSTXT_1                0.993656
# PREV_MALIG_TY_OSTXT                0.993075
# REJ_CHRONIC_PA                     0.993001
# MALIG_TY_OSTXT                     0.992405
# CANCER_FREE_INT_DON                0.992060
# COD_PA                             0.991314
# REJ_ACUTE_PA                       0.990068
# PANCREATIT_PA                      0.990063
# COD2_KI                            0.990062
# ANAST_LK_PA                        0.990056
# BIOP_ISLET_PA                      0.990054
# GRF_VASC_THROMB_PA                 0.990054
# BLEED_PA                           0.990049
# INFECT_PA                          0.990047
# GRF_FAIL_CAUSE_TY_PA               0.990017
# INSULIN_PA                         0.989981
# METHOD_BLOOD_SUGAR_CONTROL_PA      0.989978
# FAILDATE_PA                        0.989975
# WLPA                               0.989940
# PRE_AVG_INSULIN_USED_TRR           0.989326
# OTHER_INF_CONF_DON                 0.988791
# L_FIN_RESIST_TX                    0.988782
# L_FIN_FLOW_RATE_TX                 0.988763
# TXLIV                              0.988696
# R_FIN_RESIST_TX                    0.988461
# R_FIN_FLOW_RATE_TX                 0.988457
# C_PEPTIDE_PA_TCR                   0.987605
# MULTIORG                           0.986297
# RESUSCIT_DUR                       0.986277
# ACADEMIC_LEVEL_TRR                 0.985836
# ACADEMIC_PRG_TRR                   0.985836
# BLOOD_INF_CONF_DON                 0.985237
# INSULIN_DEP_DON                    0.983911
# HIST_INSULIN_DEP_DON               0.983911
# DIABDUR_DON                        0.983838
# URINE_INF_CONF_DON                 0.982373
# WARM_ISCH_TM_DON                   0.982138
# OTHER_INF_OSTXT_DON                0.981833
# ACUTE_REJ_EPI_PA                   0.981683
# ACADEMIC_LEVEL_TCR                 0.980409
# ACADEMIC_PRG_TCR                   0.980408
# SURG_INCIS                         0.979878
# FIN_RESIST_TX                      0.979217
# TRTREJ1Y_PA                        0.979066
# WLLI                               0.978635
# TRTREJ6M_PA                        0.977233
# PREV_MALIG_TY                      0.977202
# COD_OSTXT_DON                      0.975873
# MALIG_TY                           0.975149
# INO_PROCURE_AGENT_2                0.970954
# PA_PRESERV_TM                      0.970251
# GRF_FAIL_CAUSE_OSTXT_KI            0.970080
# DIAG_PA                            0.969476
# COMPL_ANASLK                       0.968648
# COMPL_ABSC                         0.968648
# COMPL_PANCREA                      0.968648
# DAYSWAIT_CHRON_PA                  0.967984
# END_STAT_PA                        0.967984
# PRI_PAYMENT_TRR_PA                 0.967464
# ART_RECON                          0.966979
# VEN_EXT_GRF                        0.966947
# OPER_TECH                          0.966631
# VASC_MGMT                          0.966583
# GRF_PLACEM                         0.966581
# DUCT_MGMT                          0.966565
# GTIME_PA                           0.966527
# GRF_STAT_PA                        0.966375
# GSTATUS_PA                         0.966375
# TX_PROCEDUR_TY_PA                  0.966375
# PREV_PA_TX                         0.966375
# TXPAN                              0.966375
# TX_TYPE                            0.966211
# WLKP                               0.966114
# CONTROLLED_DON                     0.965988
# CORE_COOL_DON                      0.965964
# WLKI                               0.965491
# COD_OSTXT_KI                       0.963852
# DIAG_OSTXT_KI                      0.961276
# LIV_DON_TY_OSTXT                   0.961169
# CREAT_CLEAR_DATE                   0.960117
# CONTIN_COCAINE_DON                 0.959635
# CREAT_CLEAR                        0.954463
# RETXDATE_KI                        0.954066
# PREV_KI_DATE                       0.949293
# PRVTXDIF_KI                        0.949092
# REC_ON_PUMP                        0.947546
# PRI_PAYMENT_TCR_PA                 0.943420
# MALIG_TCR_PA                       0.943399
# HCV_NAT                            0.938168
# HBV_NAT                            0.938167
# HIV_NAT                            0.938166
# DGN2_TCR                           0.937696
# EBV_DNA_DON                        0.937556
# PULM_INF_CONF_DON                  0.933124
# DIET_DON                           0.929494
# DIURETICS_DON                      0.929494
# OTHER_HYPERTENS_MED_DON            0.929494
# HYPERTENS_DUR_DON                  0.929253
# RESUM_MAINT_DIAL_DT                0.928864
# RESUM_MAINT_DIAL                   0.928864
# LIPASE                             0.916788
# AMYLASE                            0.915265
# HCV_NAT_DON                        0.914374
# HBV_NAT_DON                        0.914374
# HIV_NAT_DON                        0.914374
# DGN_OSTXT_TCR                      0.912496
# EBV_TEST_DON                       0.908245
# EBV_IGM_DON                        0.905663
# EBV_IGG_DON                        0.905661
# LT_KI_GLOMERUL                     0.903395
# RT_KI_GLOMERUL                     0.901426
# CONTIN_CIG_DON                     0.894573
# HBV_SURF_TOTAL                     0.892610
# HCV_TEST_DON                       0.891080
# COD_KI                             0.888369
# PT_OTH3_OSTXT_DON                  0.888271
# INO_PROCURE_AGENT_1                0.882557
# HBV_DNA_DON                        0.880990
# HCV_RNA_DON                        0.880597
# GRF_FAIL_CAUSE_TY_KI               0.880048
# CMV_IGM_DON                        0.879979
# CMV_NUCLEIC_DON                    0.879979
# CMV_IGG_DON                        0.879978
# FAILDATE_KI                        0.879247
# CMV_TEST_DON                       0.877759
# HBV_TEST_DON                       0.877309
# KI_CREAT_PREOP                     0.876871
# KI_PROC_TY                         0.873569
# HAPLO_TY_MATCH_DON                 0.873399
# EDUCATION_DON                      0.872695
# HCV_RIBA_DON                       0.864014
# HCV_ANTIBODY_DON                   0.864013
# CONTIN_OTH_DRUG_DON                0.861837
# OTHER_INF_DON                      0.855138
# LIV_DON_TY                         0.841973
# VAL_DT_LDR                         0.841074
# STATUS_LDR                         0.840383
# PT_OTH2_OSTXT_DON                  0.825999
# ADMIT_DATE_DON                     0.816772
# RDDR2                              0.812246
# RDDR1                              0.811523
# RDA2                               0.811247
# RDB2                               0.810942
# RDB1                               0.810594
# RDA1                               0.810578
# INACT_REASON_CD                    0.807975
# HBSAB_DON                          0.807570
# EBV_IGM_CAD_DON                    0.807525
# EBV_IGG_CAD_DON                    0.807522
# PREV_PREG                          0.802803
# INSULIN_DON                        0.789651
# ARGININE_DON                       0.789637
# CDC_RISK_HIV_DON                   0.788710
# REC_ON_ICE                         0.771434
# SSDMF_DEATH_DATE                   0.766816
# GFR_DATE                           0.765559
# END_CPRA_DETAIL                    0.760007
# PT_OTH1_OSTXT_DON                  0.756445
# FUNC_STAT_TRF                      0.746527
# GFR                                0.733060
# INOTROP_AGENTS                     0.732077
# HEPARIN_DON                        0.729149
# KDPI                               0.708846
# KDRI_RAO                           0.708846
# KDRI_MED                           0.708846
# PT_DIURETICS_DON                   0.706632
# PT_T3_DON                          0.706626
# PT_STEROIDS_DON                    0.706594
# PT_T4_DON                          0.706552
# WORK_INCOME_TRR                    0.705825
# SGPT_DON                           0.701402
# TBILI_DON                          0.700528
# SGOT_DON                           0.699770
# BUN_DON                            0.697512
# ACUTE_REJ_EPI_KI                   0.697498
# CREAT_DON                          0.697482
# ORG_REC_ON                         0.697352
# INTRACRANIAL_CANCER_DON            0.697317
# SKIN_CANCER_DON                    0.697317
# EXTRACRANIAL_CANCER_DON            0.697317
# ANTIHYPE_DON                       0.697017
# VASODIL_DON                        0.697017
# HIST_OTH_DRUG_DON                  0.697006
# CLIN_INFECT_DON                    0.697001
# HIST_DIABETES_DON                  0.696048
# HEP_C_ANTI_DON                     0.695979
# ECD_DONOR                          0.695949
# NON_HRT_DON                        0.695750
# REFERRAL_DATE                      0.695477
# PERM_STATE_TRR                     0.691975
# INIT_CURRENT_PRA                   0.690041
# PUMP_KI                            0.681286
# AGE_DIAB                           0.671146
# INIT_PEAK_PRA                      0.668237
# CARDARREST_NEURO                   0.668045
# INOTROP_SUPPORT_DON                0.661728
# VAL_DT_DDR                         0.648115
# DDAVP_DON                          0.647992
# HIST_COCAINE_DON                   0.647984
# TATTOOS                            0.647984
# PROTEIN_URINE                      0.647979
# RT_KI_BIOPSY                       0.647913
# LT_KI_BIOPSY                       0.647850
# CMV_DON                            0.647325
# VDRL_DON                           0.647313
# DEATH_CIRCUM_DON                   0.647202
# DEATH_MECH_DON                     0.647196
# COD_CAD_DON                        0.647196
# TRTREJ1Y_KI                        0.647090
# URINE_INF_DON                      0.646966
# BLOOD_INF_DON                      0.646966
# PULM_INF_DON                       0.646966
# STATUS_DDR                         0.646964
# CMV_IGM                            0.628247
# CMV_IGG                            0.628195
# LOS                                0.625258
# TRTREJ6M_KI                        0.621648
# EBV_SEROSTATUS                     0.621373
# EGFR_CKDEPI_TRR_PRETX              0.613755
# PRE_TX_TXFUS                       0.613564
# CREAT_TRR                          0.613432
# RECOVERY_DATE                      0.611710
# ADMISSION_DATE                     0.611341
# COMPOSITE_DEATH_DATE               0.610409
# MED_COND_TRR                       0.606326
# HIST_CIG_DON                       0.605221
# HIST_CANCER_DON                    0.599901
# CANCER_SITE_DON                    0.599901
# DIABETES_DON                       0.599697
# HIST_HYPERTENS_DON                 0.599616
# DIAL_DATE                          0.599322
# RECOV_OUT_US                       0.584214
# EGFR_CKDEPI_DON                    0.574825
# HCV_SEROSTATUS                     0.562493
# BMI_DON_CALC                       0.562424
# HGT_CM_DON_CALC                    0.561503
# PRI_PAYMENT_TRR_KI                 0.561177
# HBV_CORE_DON                       0.560072
# COLD_ISCH_KI                       0.546117
# WGT_KG_DON_CALC                    0.544000
# END_STAT_KI                        0.542013
# DAYSWAIT_CHRON_KI                  0.542013
# HIV_SEROSTATUS                     0.537774
# CMV_STATUS                         0.512851
# EGFR_CKDEPI_TRR_DISCHARGE          0.510703
# SERUM_CREAT                        0.509811
# HBV_CORE                           0.509217
# HBV_SUR_ANTIGEN                    0.509064
# INIT_CPRA                          0.508799
# DIAG_KI                            0.503743
# BMI_CALC                           0.502166
# MALIG_TRR                          0.500821
# EGFR_CKDEPI_TRF                    0.499910
# EGFR_CKDEPI_TRF_TIME               0.499910
# HGT_CM_CALC                        0.499887
# FIRST_WK_DIAL                      0.499118
# GTIME_KI                           0.498880
# DIAL_TRR                           0.498074
# HBV_SUR_ANTIGEN_DON                0.497950
# GRF_STAT_KI                        0.496269
# GSTATUS_DTHCNS_KI                  0.496194
# DWFG_KI                            0.496194
# TX_PROCEDUR_TY_KI                  0.496194
# TXKID                              0.496194
# GSTATUS_KI                         0.496194
# ACTIVATE_DATE                      0.495482
# WGT_KG_CALC                        0.494621
# HOME_STATE_DON                     0.493752
# DISCHARGE_DATE                     0.493507
# DDR2                               0.493077
# DON_RETYP                          0.493043
# RDR2                               0.493014
# HLAMIS                             0.492826
# DRMIS                              0.492719
# DA2                                0.492491
# DISTANCE                           0.492158
# RA2                                0.491938
# BMIS                               0.491500
# AMIS                               0.491475
# PREV_KI_TX                         0.491375
# DB2                                0.491146
# RB2                                0.491068
# VAL_DT_TRR                         0.490218
# FUNC_STAT_TRR                      0.490178
# PX_STAT_DATE                       0.490062
# PTIME                              0.490057
# PX_STAT                            0.489957
# RDR1                               0.489891
# DDR1                               0.489682
# CITIZENSHIP_DON                    0.489503
# DA1                                0.489474
# DB1                                0.489474
# RA1                                0.489452
# RB1                                0.489444
# VAL_DT_TCR                         0.489008
# ABO_MAT                            0.487451
# AGE_DON                            0.487369
# ABO_DON                            0.487359
# GENDER_DON                         0.487348
# SHARE_TY                           0.487347
# AGE                                0.487347
# ETHCAT_DON                         0.487346
# NPKID                              0.487346
# NPPAN                              0.487346
# MALIG                              0.487346
# STATUS_TCR                         0.487346
# DONOR_ID                           0.487346
# STATUS_TRR                         0.487346
# AGE_GROUP                          0.487346
# PAYBACK                            0.487346
# TRR_ID_CODE                        0.487346
# PSTATUS                            0.487346
# LT_ONE_WEEK_DON                    0.487346
# PREV_TX                            0.487346
# PREV_TX_ANY                        0.487346
# DON_TY                             0.487346
# ORGAN                              0.487346
# TX_DATE                            0.487346
# DIALYSIS_DATE                      0.467152
# END_CPRA                           0.429100
# WORK_INCOME_TCR                    0.393424
# TOT_SERUM_ALBUM                    0.336887
# DRUGTRT_COPD                       0.334325
# DAYSWAIT_ALLOC                     0.228613
# WT_QUAL_DATE                       0.227301
# DONATION                           0.166692
# REM_CD                             0.146609
# PRI_PAYMENT_TCR_KI                 0.137078
# MALIG_TCR_KI                       0.136781
# DGN_TCR                            0.131853
# PERIP_VASC                         0.124681
# EDUCATION                          0.117206
# DIAB                               0.115184
# ON_DIALYSIS                        0.112191
# INIT_BMI_CALC                      0.099941
# INIT_HGT_CM                        0.094921
# END_BMI_CALC                       0.086932
# INIT_WGT_KG                        0.086683
# BMI_TCR                            0.059033
# HGT_CM_TCR                         0.056505
# INIT_STAT                          0.050552
# WGT_KG_TCR                         0.046252
# DAYSWAIT_CHRON                     0.045634
# INIT_AGE                           0.045456
# END_STAT                           0.045442
# WL_ORG                             0.045441
# A1                                 0.045441
# NUM_PREV_TX                        0.045441
# DR2                                0.045441
# WL_ID_CODE                         0.045441
# A2                                 0.045441
# B1                                 0.045441
# B2                                 0.045441
# DR1                                0.045441
# INIT_DATE                          0.045441
# END_DATE                           0.045441
# EXH_VASC_ACCESS                    0.021760
# EXH_PERIT_ACCESS                   0.021760
# FUNC_STAT_TCR                      0.020256
# PERM_STATE                         0.018386
# CITIZENSHIP                        0.009745
# GENDER                             0.000000
# Year                               0.000000
# ABO                                0.000000
# ETHNICITY                          0.000000
# ETHCAT                             0.000000
# PT_CODE                            0.000000
# REGION                             0.000000
# LISTING_CTR_CODE                   0.000000
# DATA_TRANSPLANT                    0.000000
# DATA_WAITLIST                      0.000000
# CTR_CODE                           0.000000
# OPO_CTR_CODE                       0.000000
# INIT_OPO_CTR_CODE                  0.000000
# END_OPO_CTR_CODE                   0.000000
# index                              0.000000
# Name: percent_null, dtype: float64

# %%
# Kidney Followup Data
kid_followup_nulls = pd.DataFrame()

for col in columns:
    
    query = f"""SELECT \'{col}\' as column, 1-CAST(COUNT("{col}") as float)/CAST(COUNT(*) as float) as percent_null FROM kidney_followup_data;"""
    tmp_table = pd.read_sql_query(query, conn)
    print(f"{col}")
    kid_followup_nulls = pd.concat([kid_followup_nulls, tmp_table])

# %%
# Deceased Donor Data
dec_donor_nulls = pd.DataFrame()

for col in columns:
    
    query = f"""SELECT \'{col}\' as column, 1-CAST(COUNT("{col}") as float)/CAST(COUNT(*) as float) as percent_null FROM deceased_donor_data;"""
    tmp_table = pd.read_sql_query(query, conn)
    print(f"{col}")
    dec_donor_nulls = pd.concat([dec_donor_nulls, tmp_table])
